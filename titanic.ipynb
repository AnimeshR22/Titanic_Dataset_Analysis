# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/test-file/tested.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
ds_read=pd.read_csv('/kaggle/input/test-file/tested.csv')
ds_read
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
ds_read.shape
# Out:
# (418, 12)

# %%
pd.set_option("display.max.rows",None)
ds_read.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
# 20          912         0       1
# 21          913         0       3
# 22          914         1       1
# 23          915         0       1
# 24          916         1       1
# 25          917         0       3
# ...

# %%
pd.set_option("display.max.rows",None)
p=ds_read.tail(20)
p
# Out:
#      PassengerId  Survived  Pclass  \
# 398         1290         0       3
# 399         1291         0       3
# 400         1292         1       1
# 401         1293         0       2
# 402         1294         1       1
# 403         1295         0       1
# 404         1296         0       1
# 405         1297         0       2
# 406         1298         0       2
# 407         1299         0       1
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 398                   Larsson-Rondberg, Mr. Edvard A    male  22.0      0
# ...

# %%
import csv
with open('/kaggle/input/test-file/tested.csv','r')as f:
 titanic = list(csv.reader(f,delimiter=';'))
    #print 3 Rows
print("Printing 3 rows\n{}".format(titanic[:3]))
# Out:
# Printing 3 rows
# [['PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked'], ['892,0,3,"Kelly, Mr. James",male,34.5,0,0,330911,7.8292,,Q'], ['893,1,3,"Wilkes, Mrs. James (Ellen Needs)",female,47,1,0,363272,7,,S']]

# %%
ds_read.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
ds_read.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
ds_read.describe(include=object)
# Out:
#                     Name   Sex    Ticket            Cabin Embarked
# count                418   418       418               91      418
# unique               418     2       363               76        3
# top     Kelly, Mr. James  male  PC 17608  B57 B59 B63 B66        S
# freq                   1   266         5                3      270

# %%
print('The Column Names:\n{}'.format(ds_read.columns))
# Out:
# The Column Names:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
ds_read1=pd.read_csv('/kaggle/input/test-file/tested.csv')
print('Checking for the null values in the given dataset: \n')
q=ds_read1.isnull()
q.head(20)
# Out:
# Checking for the null values in the given dataset:
#     PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0         False     False   False  False  False  False  False  False   False
# 1         False     False   False  False  False  False  False  False   False
# 2         False     False   False  False  False  False  False  False   False
# 3         False     False   False  False  False  False  False  False   False
# 4         False     False   False  False  False  False  False  False   False
# 5         False     False   False  False  False  False  False  False   False
# 6         False     False   False  False  False  False  False  False   False
# 7         False     False   False  False  False  False  False  False   False
# 8         False     False   False  False  False  False  False  False   False
# 9         False     False   False  False  False  False  False  False   False
# ...

# %%
print('Total No of Null values: ')
ds_read1.isnull().sum()
# Out:
# Total No of Null values:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
grp = ds_read.groupby('Sex')
grp1=grp.get_group('male')
grp1.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 2           894         0       2
# 3           895         0       3
# 5           897         0       3
# 7           899         0       2
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 13          905         0       2
# 16          908         0       2
# 17          909         0       3
# 20          912         0       1
# 21          913         0       3
# 23          915         0       1
# 25          917         0       3
# 27          919         0       3
# 28          920         0       1
# 29          921         0       3
# 30          922         0       2
# 31          923         0       2
# 34          926         0       1
# 35          927         0       3
# 38          930         0       3
# 39          931         0       3
# 40          932         0       3
# 41          933         0       1
# ...

# %%
grp2=grp.get_group('female')
grp2.head(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# 14           906         1       1
# 15           907         1       2
# 18           910         1       3
# 19           911         1       3
# 22           914         1       1
# 24           916         1       1
# 26           918         1       1
# 32           924         1       3
# 33           925         1       3
# 36           928         1       3
# 37           929         1       3
# 43           935         1       2
# 44           936         1       1
# 48           940         1       1
# 49           941         1       3
# 52           944         1       2
# 53           945         1       1
# 59           951         1       1
# 63           955         1       3
# 65           957         1       2
# ...

# %%
ds_new=ds_read1.dropna()
ds_new
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# 34           926         0       1
# 44           936         1       1
# 46           938         0       1
# 48           940         1       1
# 50           942         0       1
# 53           945         1       1
# 57           949         0       3
# 59           951         1       1
# 64           956         0       1
# 68           960         0       1
# 69           961         1       1
# 73           965         0       1
# 74           966         1       1
# 75           967         0       1
# 77           969         1       1
# 81           973         0       1
# 92           984         1       1
# 96           988         1       1
# 100          992         1       1
# 109         1001         0       2
# ...

# %%
ds_new.shape
# Out:
# (87, 12)

# %%
ds_new.sort_values(by=['Pclass','Age','Cabin'])
# Out:
#      PassengerId  Survived  Pclass  \
# 196         1088         0       1
# 64           956         0       1
# 395         1287         1       1
# 182         1074         1       1
# 26           918         1       1
# 390         1282         0       1
# 12           904         1       1
# 150         1042         1       1
# 287         1179         0       1
# 50           942         0       1
# 364         1256         1       1
# 272         1164         1       1
# 184         1076         1       1
# 92           984         1       1
# 252         1144         0       1
# 53           945         1       1
# 73           965         0       1
# 156         1048         1       1
# 335         1227         0       1
# 306         1198         0       1
# 400         1292         1       1
# 34           926         0       1
# 68           960         0       1
# 371         1263         1       1
# 75           967         0       1
# ...

# %%
print('TOP 10 HIGHEST TICKET FAIR:\n')
cost=ds_new.sort_values('Fare', ascending =False )
cost.head(10)
# Out:
# TOP 10 HIGHEST TICKET FAIR:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 69           961         1       1
# 53           945         1       1
# 59           951         1       1
# 64           956         0       1
# 142         1034         0       1
# 24           916         1       1
# 184         1076         1       1
# 202         1094         0       1
# 114         1006         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 59                         Chaudanson, Miss. Victorine  female  36.0      0
# 64                         Ryerson, Master. John Borie    male  13.0      2
# 142                         Ryerson, Mr. Arthur Larned    male  61.0      1
# ...

# %%
print('The data which is required for analyzing data:\n')
Analyze_ds = ds_new.drop(["PassengerId", "Name", "Ticket", "Cabin"], axis=1)
Analyze_ds
# Out:
# The data which is required for analyzing data:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 12          1       1  female  23.0      1      0   82.2667        S
# 14          1       1  female  47.0      1      0   61.1750        S
# 24          1       1  female  48.0      1      3  262.3750        C
# 26          1       1  female  22.0      0      1   61.9792        C
# 28          0       1    male  41.0      0      0   30.5000        S
# 34          0       1    male  30.0      1      0   57.7500        C
# 44          1       1  female  45.0      1      0   52.5542        S
# 46          0       1    male  45.0      0      0   29.7000        C
# 48          1       1  female  60.0      0      0   76.2917        C
# 50          0       1    male  24.0      1      0   60.0000        S
# 53          1       1  female  28.0      3      2  263.0000        S
# 57          0       3    male  25.0      0      0    7.6500        S
# ...

# %% [markdown]
# # **EDA(EXPLORATORY DATA ANALYSIS)**

# %%
import seaborn as sns
sns.histplot(data=Analyze_ds, x="Age",bins=50, kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.countplot(data=Analyze_ds, x='Survived')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.catplot(x='Pclass', y='Age', hue='Sex', kind='swarm', data=Analyze_ds)

# %%
sns.heatmap(Analyze_ds.corr(), annot=True, cmap='magma')
# Out:
# <AxesSubplot:>

# %%
sns.displot(data=Analyze_ds, x='Age', hue='Survived', kind='kde', fill=True)
